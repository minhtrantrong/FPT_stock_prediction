# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
url='https://s.cafef.vn/Lich-su-giao-dich-FPT-1.chn'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
#Check the length of the first 12 rows
for row in tr_elements[:22]:
    print(row, "/n Length: ", len(row))
# Out:
# <Element tr at 0x2affcb74630> /n Length:  5
# <Element tr at 0x2affcb74c20> /n Length:  12
# <Element tr at 0x2affcb74ef0> /n Length:  4
# <Element tr at 0x2affcb74f40> /n Length:  15
# <Element tr at 0x2affcb74ea0> /n Length:  15
# <Element tr at 0x2affcb74f90> /n Length:  15
# <Element tr at 0x2affcba0040> /n Length:  15
# <Element tr at 0x2affcba0090> /n Length:  15
# <Element tr at 0x2affcba00e0> /n Length:  15
# <Element tr at 0x2affcba0130> /n Length:  15
# <Element tr at 0x2affcba0180> /n Length:  15
# <Element tr at 0x2affcba01d0> /n Length:  15
# <Element tr at 0x2affcba0220> /n Length:  15
# <Element tr at 0x2affcba0270> /n Length:  15
# <Element tr at 0x2affcba02c0> /n Length:  15
# <Element tr at 0x2affcba0310> /n Length:  15
# <Element tr at 0x2affcba0360> /n Length:  15
# <Element tr at 0x2affcba03b0> /n Length:  15
# <Element tr at 0x2affcba0400> /n Length:  15
# <Element tr at 0x2affcba0450> /n Length:  15
# <Element tr at 0x2affcba04a0> /n Length:  15
# <Element tr at 0x2affcba04f0> /n Length:  15

# %%
# list all col name
col_list = ["Ngay", "Gia d/c", "Gia dong cua", "Thay doi", "up-down",
            "GD-KL", "GD-GT", "TT-KL", "TT-GT", "Gia mo cua", 
            "Gia cao nhat", "Gia thap nhat", "C13", "C14", "C15" ]
#Create empty list
col=[]
#For each row, store each first element (header) and an empty list
for t in col_list:
    col.append((t,[]))

print(col, len(col))
# Out:
# [('Ngay', []), ('Gia d/c', []), ('Gia dong cua', []), ('Thay doi', []), ('up-down', []), ('GD-KL', []), ('GD-GT', []), ('TT-KL', []), ('TT-GT', []), ('Gia mo cua', []), ('Gia cao nhat', []), ('Gia thap nhat', []), ('C13', []), ('C14', []), ('C15', [])] 15

# %%
#Since out first row is the header, data is stored on the second row onwards
i = 1
for item in tr_elements[3].iterchildren():
    data=item.text_content()
    print(i, ": ", data)
    i+=1
# Out:
# 1 :  09/09/2021
# 2 :  93.20
# 3 :  93.20
# 4 :  0.10 (0.11 %)
# 5 :
# 6 :  1,393,700
# 7 :  129,780,000,000
# 8 :  100,000
# 9 :  9,589,000,000
# 10 :  93.10
# 11 :  93.90
# 12 :  92.80
# 13 :  0
# 14 :  0
# 15 :  0

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(3,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=15:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df
# Out:
#           Ngay Gia d/c Gia dong cua         Thay doi up-down       GD-KL  \
# 0   09/09/2021  93.20        93.20     0.10 (0.11 %)          1,393,700
# 1   08/09/2021  93.10        93.10   -0.40 (-0.43 %)          1,453,800
# 2   07/09/2021  93.50        93.50   -1.40 (-1.48 %)          2,290,600
# 3   06/09/2021  94.90        94.90     2.50 (2.71 %)          3,124,600
# 4   01/09/2021  92.40        92.40     0.00 (0.00 %)          1,353,300
# 5   31/08/2021  92.40        92.40     0.20 (0.22 %)          1,952,500
# 6   30/08/2021  92.20        92.20     0.20 (0.22 %)          1,494,800
# 7   27/08/2021  92.00        92.00     0.60 (0.66 %)          1,896,200
# 8   26/08/2021  91.40        91.40   -0.50 (-0.54 %)          1,758,700
# 9   25/08/2021  91.90        91.90     0.00 (0.00 %)          1,344,000
# 10  24/08/2021  91.90        91.90     0.90 (0.99 %)          3,081,500
# 11  23/08/2021  91.00        91.00   -1.80 (-1.94 %)          3,436,600
# 12  20/08/2021  92.80        92.80   -1.70 (-1.80 %)          4,349,300
# 13  19/08/2021  94.50        94.50     0.50 (0.53 %)          2,721,600
# 14  18/08/2021  94.00        94.00     0.20 (0.21 %)          1,951,000
# 15  17/08/2021  93.80        93.80   -0.80 (-0.85 %)          2,801,700
# 16  16/08/2021  94.60        94.60   -0.40 (-0.42 %)          1,906,800
# 17  13/08/2021  94.00        95.00     1.20 (1.28 %)          3,618,700
# 18  12/08/2021  92.82        93.80   -2.30 (-2.39 %)          8,399,400
# 19  11/08/2021  95.09        96.10   -1.70 (-1.74 %)          4,883,200
#
#                GD-GT       TT-KL             TT-GT Gia mo cua Gia cao nhat  \
# 0   129,780,000,000     100,000     9,589,000,000      93.10        93.90
# 1   135,781,000,000     170,000    16,445,500,000      93.50        94.20
# 2   216,065,000,000     280,000    27,465,000,000      95.30        95.30
# 3   291,339,000,000      50,400     4,869,168,000      92.40        94.90
# 4   125,334,000,000     240,000    22,920,000,000      92.10        93.00
# 5   180,576,000,000     425,000    40,269,200,000      92.30        93.20
# 6   138,071,000,000     166,067    15,466,066,000      93.00        93.00
# 7   173,355,000,000     449,600    42,642,130,000      91.00        92.00
# 8   161,959,000,000     240,000    22,716,000,000      92.00        92.90
# 9   123,143,000,000     640,700    60,737,255,000      92.40        92.40
# 10  279,875,000,000   2,128,465   199,501,024,450      91.50        92.00
# 11  314,747,000,000   1,194,600   114,203,760,000      92.50        92.50
# 12  405,428,000,000   1,056,900   102,155,500,000      94.50        94.70
# 13  256,963,000,000     421,300    40,974,008,000      95.00        95.00
# 14  183,417,000,000      64,000     6,272,000,000      93.80        94.90
# 15  263,601,000,000     452,400    44,063,760,000      94.10        94.60
# 16  180,442,000,000     111,800    10,678,020,000      95.00        95.20
# 17  339,384,000,000     514,500    49,901,750,000      93.10        95.00
# 18  795,485,000,000     524,800    51,955,200,000      95.80        96.00
# 19  472,971,000,000     914,900    91,918,430,000      97.70        97.80
#
#    Gia thap nhat  C13  C14  C15
# 0         92.80     0    0    0
# 1         92.80     0    0    0
# 2         93.50     0    0    0
# 3         92.30     0    0    0
# 4         92.10     0    0    0
# 5         92.00     0    0    0
# 6         92.10     0    0    0
# 7         90.60     0    0    0
# 8         91.20     0    0    0
# 9         91.00     0    0    0
# 10        89.90     0    0    0
# 11        91.00     0    0    0
# 12        91.10     0    0    0
# 13        93.80     0    0    0
# 14        93.80     0    0    0
# 15        93.50     0    0    0
# 16        94.40     0    0    0
# 17        93.00     0    0    0
# 18        93.40     0    0    0
# 19        96.10     0    0    0
