# %%
import pandas as pd
import psycopg2
import time

# %%
pg_config = "dbname=stock user=postgres password=123qwe host=127.0.0.1 port=5432"
pg_conn = psycopg2.connect(pg_config)
print("PostgreSQL DB connected")
curs = pg_conn.cursor()
# Out:
# PostgreSQL DB connected

# %%
query = "SELECT * FROM fpt"
fpt_df = pd.read_sql(query, con=pg_conn, parse_dates = True)

# %%
fpt_df = fpt_df.set_index("date")[::-1]

# %%
fpt_df.head()
# Out:
#             open_price  close_price  highest_price  lowest_price  change  \
# date
# 02/01/2007      440000       440000         450000        440000   -10.0
# 03/01/2007      450000       450000         450000        440000    10.0
# 04/01/2007      472000       472000         472000        472000    22.0
# 05/01/2007      495000       495000         495000        495000    23.0
# 08/01/2007      510000       490000         510000        490000    -5.0
#
#             ex_match     ex_value  deal_match  deal_value
# date
# 02/01/2007     81170  35939000000           0           0
# 03/01/2007     74660            0           0           0
# 04/01/2007    148510  70097000000           0           0
# 05/01/2007    377800            0           0           0
# 08/01/2007    351470  90341000000           0           0

# %%
fpt_df.describe()
# Out:
#           open_price    close_price  highest_price   lowest_price  \
# count    3661.000000    3661.000000    3661.000000    3661.000000
# mean    78024.296367   77980.128107   78792.338159   77252.758263
# std     89165.335779   89042.011993   89899.248794   88271.647505
# min     32200.000000   32299.000000   32600.000000   32100.000000
# 25%     46200.000000   46200.000000   46700.000000   45900.000000
# 50%     50500.000000   50500.000000   51000.000000   50000.000000
# 75%     68000.000000   68000.000000   69000.000000   67500.000000
# max    665000.000000  665000.000000  672000.000000  665000.000000
#
#             change      ex_match      ex_value    deal_match    deal_value
# count  3661.000000  3.661000e+03  3.661000e+03  3.661000e+03  3.661000e+03
# mean      0.036329  8.058322e+05  5.088467e+10  1.722543e+05  1.019718e+10
# std       4.564319  9.055161e+05  6.201816e+10  7.675840e+05  4.228275e+10
# ...

# %%
fpt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3661 entries, 02/01/2007 to 10/09/2021
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   open_price     3661 non-null   int64
#  1   close_price    3661 non-null   int64
#  2   highest_price  3661 non-null   int64
#  3   lowest_price   3661 non-null   int64
#  4   change         3661 non-null   float64
#  5   ex_match       3661 non-null   int64
#  6   ex_value       3661 non-null   int64
#  7   deal_match     3661 non-null   int64
#  8   deal_value     3661 non-null   int64
# dtypes: float64(1), int64(8)
# memory usage: 286.0+ KB

# %%
fpt_df["open_price"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
fpt_df["ex_value"].plot(figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='date'>
